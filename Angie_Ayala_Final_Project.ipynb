# %% [markdown]
# <a href="https://colab.research.google.com/github/angienar/Data110-Fall25/blob/main/Angie_Ayala_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Final Project:**
#
# Author: Angie Ayala
#
# Class: Data110
#
# Date: December 16, 2025

# %%
# !pip install joypy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from joypy import joyplot

# %% [markdown]
# ##EDA:

# %%
traffic_violations = pd.read_csv('Traffic_Violations_20251210.csv', on_bad_lines='skip', engine='python')

# %%
traffic_violations.head()
# Out:
#                                   SeqID Date Of Stop Time Of Stop Agency  \
# 0  9a89cc84-fac6-4e7d-aa25-5414e2a29f8a   12/09/2025     07:01:00    MCP
# 1  9a89cc84-fac6-4e7d-aa25-5414e2a29f8a   12/09/2025     07:01:00    MCP
# 2  0e3e3c4b-0b26-425e-8411-c8b83a4f2e4f   12/09/2025     06:59:00    MCP
# 3  0e3e3c4b-0b26-425e-8411-c8b83a4f2e4f   12/09/2025     06:59:00    MCP
# 4  0e3e3c4b-0b26-425e-8411-c8b83a4f2e4f   12/09/2025     06:59:00    MCP
#
#                              SubAgency  \
# 0  Headquarters and Special Operations
# 1  Headquarters and Special Operations
# 2              1st District, Rockville
# 3              1st District, Rockville
# 4              1st District, Rockville
#
#                                          Description  \
# 0  FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DI...
# 1         EXCEEDING THE POSTED SPEED LIMIT OF 45 MPH
# 2                       FAILURE TO STOP AT STOP SIGN
# 3  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# ...

# %%
traffic_violations.tail()
# Out:
#                                         SeqID Date Of Stop Time Of Stop  \
# 2070992  b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb   01/01/2012     00:52:00
# 2070993  b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb   01/01/2012     00:52:00
# 2070994  b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb   01/01/2012     00:52:00
# 2070995  b1463ded-4b1a-4e7f-ada9-9211bbdc1cbb   01/01/2012     00:52:00
# 2070996  845c2732-d70b-42ef-bde8-603f9563aa28   01/01/2012     00:43:00
#
#         Agency                            SubAgency  \
# 2070992    MCP          3rd District, Silver Spring
# 2070993    MCP          3rd District, Silver Spring
# 2070994    MCP          3rd District, Silver Spring
# 2070995    MCP          3rd District, Silver Spring
# 2070996    MCP  Headquarters and Special Operations
#
#                                                Description  \
# 2070992  PERSON DRIVING MOTOR VEHICLE WHILE LICENSE SUS...
# 2070993  PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUB...
# ...

# %%
traffic_violations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2070997 entries, 0 to 2070996
# Data columns (total 43 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   SeqID                    object
#  1   Date Of Stop             object
#  2   Time Of Stop             object
#  3   Agency                   object
#  4   SubAgency                object
#  5   Description              object
#  6   Location                 object
#  7   Latitude                 float64
#  8   Longitude                float64
#  9   Accident                 object
#  10  Belts                    object
#  11  Personal Injury          object
#  12  Property Damage          object
#  13  Fatal                    object
#  14  Commercial License       object
#  15  HAZMAT                   object
#  16  Commercial Vehicle       object
#  17  Alcohol                  object
#  18  Work Zone                object
#  19  Search Conducted         object
# ...

# %%
traffic_violations.describe()
# Out:
#            Latitude     Longitude          Year
# count  2.070997e+06  2.070997e+06  2.060352e+06
# mean   3.613716e+01 -7.129990e+01  2.007618e+03
# std    1.032204e+01  2.036585e+01  8.487971e+01
# min    0.000000e+00 -1.512560e+02  0.000000e+00
# 25%    3.901642e+01 -7.719297e+01  2.003000e+03
# 50%    3.906619e+01 -7.708754e+01  2.008000e+03
# 75%    3.913722e+01 -7.702696e+01  2.013000e+03
# max    4.154316e+01  3.906444e+01  9.999000e+03

# %% [markdown]
# ##First Visualization:

# %%
plt.style.use('ggplot')

# %%
traffic_violations['Date_Of_Stop_Month'] = pd.to_datetime(traffic_violations['Date Of Stop'], errors='coerce').dt.month

month_counts = traffic_violations['Date_Of_Stop_Month'].value_counts().sort_index()

plt.plot(month_counts.index, month_counts.values, marker='o', linestyle='-')
plt.title('Traffic Violations by Month')
plt.xlabel('Month')
plt.ylabel('Amount')

month_labels = ['January','February','March','April','May','June','July','August','September','October','November','December']
plt.xticks(range(1, 13), month_labels, rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# The first visualization I created was a line plot showing the amount of traffic violations that happened each month. The x-axis of this line plot is the month, and the y-axis is the amount. Looking at this graph I noticed that the month that has the most amount of violations March with more then 250,000 traffic violations. The month with the least number of violations is June, with fewer than 200,000.

# %% [markdown]
# ##Second Visualization:

# %%
traffic_violations['Time_of_Stop_Hour'] = pd.to_datetime(traffic_violations['Time Of Stop'], errors='coerce').dt.hour

plt.figure(figsize=(10, 5))
sns.kdeplot(traffic_violations[traffic_violations['Gender'] == 'F']['Time_of_Stop_Hour'].dropna(), bw_adjust=0.8, fill=0.5, color='red')
sns.kdeplot(traffic_violations[traffic_violations['Gender'] == 'M']['Time_of_Stop_Hour'].dropna(), bw_adjust=0.8, fill=0.5, color='green')
plt.title('Time of Stop Distribution by Gender')
plt.xlabel('Hour of Stop')
plt.ylabel('Density')
plt.legend(['Female', 'Male'])
plt.show()
# Out:
# /tmp/ipython-input-3891075441.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   traffic_violations['Time_of_Stop_Hour'] = pd.to_datetime(traffic_violations['Time Of Stop'], errors='coerce').dt.hour

# %% [markdown]
# The next visualization I created is a distribution graph, where the x-axis values are the time of the stop. The graph is divided by gender, with female represented by red and male by green. I noticed that males are stopped more between the hours of 0 to 4 and 20 to 23. Females were stopped more, 7 to 17. It seems that overall there are less stops in the morning and the most stops mid-day. There are multiple stops at the end of the day, but it is less than mid-day.

# %% [markdown]
# ##Third Visualization:

# %%
print(traffic_violations['Race'].value_counts())
# Out:
# Race
# WHITE              691233
# BLACK              656590
# HISPANIC           464857
# OTHER              138010
# ASIAN              116782
# NATIVE AMERICAN      3525
# Name: count, dtype: int64

# %%
races_to_filter = ['BLACK', 'HISPANIC', 'OTHER', 'ASIAN', 'NATIVE AMERICAN','WHITE']
filtered_race_violations = traffic_violations[traffic_violations['Race'].isin(races_to_filter)]
print(f"Filtered violations count: {len(filtered_race_violations)}")
print(f"Unique races in filtered data:\n{filtered_race_violations['Race'].value_counts()}")
# Out:
# Filtered violations count: 2070997
# Unique races in filtered data:
# Race
# WHITE              691233
# BLACK              656590
# HISPANIC           464857
# OTHER              138010
# ASIAN              116782
# NATIVE AMERICAN      3525
# Name: count, dtype: int64

# %%
race_counts = filtered_race_violations['Race'].value_counts()

plt.figure(figsize=(10, 6))
plt.barh(race_counts.index, race_counts.values, color='purple', edgecolor='black')
plt.xlabel('Count')
plt.ylabel('Race')
plt.title('Count of Traffic Violations by Race')
plt.show()

# %% [markdown]
# The visualization above is a bar graph showing the number of stops of each race. The race with the more amount of stop is black with 11,006, and the second was white with 9,931. The race with the least amount of stops is Native Americans with only 20.

# %% [markdown]
# ##Fourth Visualization:

# %%
from IPython.display import display, HTML

def folium_map(m):
    m._build_map()
    return m.html.replace('"', '&quot;')

# %%
traffic_violations['Latitude'] = pd.to_numeric(traffic_violations['Latitude'], errors='coerce')
traffic_violations['Longitude'] = pd.to_numeric(traffic_violations['Longitude'], errors='coerce')

cleaned_violations = traffic_violations.dropna(subset=['Latitude', 'Longitude'])

sample_violations = cleaned_violations.sample(n=1000, random_state=42)

# %%
import folium

# Calculate the center of the map using the mean latitude and longitude of the sampled data
map_center_latitude = sample_violations['Latitude'].mean()
map_center_longitude = sample_violations['Longitude'].mean()

# Create a Folium map centered around the average coordinates
m = folium.Map(location=[map_center_latitude, map_center_longitude], zoom_start=6)

# Add markers for each violation in the sampled data
for index, row in sample_violations.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=1,  # Small radius for individual points
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(m)

# Display the map
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ##Fifth Visualization:

# %% [markdown]
# ![Traffic Violation Type-2.png](data:image/png;base64,...)

# %% [markdown]
# [Tableau Visualisation Link](https://public.tableau.com/app/profile/angie.ayala.ruiz/viz/FinalProject_17658583783450/Sheet1)

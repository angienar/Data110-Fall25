# %% [markdown]
# <a href="https://colab.research.google.com/github/angienar/Data110-Fall25/blob/main/museum_viz_report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Smithsonian Data-Viz**

# %% [markdown]
# ##Smithsonian Air and Space Museum
#
# Author: Angie Ayala Ruiz
# Date of visit: November 24, 2025

# %% [markdown]
# ![https%3A__www.si.edu_sites_default_files_nasm-2025.jpg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Visualizations:**

# %% [markdown]
# # Infographic:

# %% [markdown]
# ![Picture1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##

# %% [markdown]
# #Map:

# %% [markdown]
# ![P.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Pie Chart:

# %% [markdown]
# ![pi.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Line Graph:

# %% [markdown]
# ![pic.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Histogram:

# %% [markdown]
# ![pict.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**Reflection:**

# %% [markdown]
# I was suprised to see there were many data visualizations throughout the museum that you would overlook unless you were searching specifically for them. It is easy to get distracted by all the cool items in the museum that you can forget to take a moment and learn about what is infront of you.
#
# Something I learned from seeing the graphs in the museum is that sometimes simplicity is best. There were many graphs in the agriculture section of the museum, and I noticed that many of them were simple yet did a great job conveying the information the reader was meant to learn
#
# It was a very enjoyable expirience to go the Smithsinian Air and Space Museum. I had fun walking through the exhibitions and learning about space, engines, and going to the moon. I liked learning new things, like how there was a pilot named Roscoe Turner whose co-pilot was a lion cub named Gilmore.
